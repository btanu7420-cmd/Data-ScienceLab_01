# %%
age=22;
print(type(age))
name='Asaha'
is_student=True
print(type(is_student))
# Out:
# <class 'int'>
# <class 'bool'>

# %%
age=20
if age>=18:
 print("Adult")
# Out:
# Adult

# %%
age=16
if age>=18:
  print("eligibe=le")
else:
  print("Not eligible")
# Out:
# Not eligible

# %%
marks=72
if marks>=90:
  print("A+")
elif marks>=75:
  print("A")
elif marks>=60:
  print("B")
elif marks>=50:
  print("C")
else:
  print("Fail")
# Out:
# B

# %%
age=25
fare=80
if age>=18 and fare>=50:
  print("Condition satisfied")
# Out:
# Condition satisfied

# %%
age=25
survived=1
if age>=18:
  if survived==1:
    print("Adult survived")
# Out:
# Adult survived

# %% [markdown]
# LIST
# ordered , indexed , mutable , can contain duplicate values , uses square brackets.

# %%
my_list=[]
my_list
[]
# Out:
# []

# %%
ages=[22,38,36,35,35]
names=["Asha","Sachin","Tashu"]
mixed=[10,"Python",3.5,True]

# %%
print(ages)
print(names)
print(mixed)
# Out:
# [22, 38, 36, 35, 35]
# ['Asha', 'Sachin', 'Tashu']
# [10, 'Python', 3.5, True]

# %%
print(ages[0])
print(ages[-1])
print(names[-1])
print(ages[1:])
print(ages[:2])
print(ages[::2])
# Out:
# 22
# 35
# Tashu
# [38, 36, 35, 35]
# [22, 38]
# [22, 36, 35]

# %%
print(ages)
ages[2]=27
print(ages)
# Out:
# [22, 38, 36, 35, 35]
# [22, 38, 27, 35, 35]

# %%
print(names)
names.append("shivani")
print(names)
# Out:
# ['Asha', 'Sachin', 'Tashu']
# ['Asha', 'Sachin', 'Tashu', 'shivani']

# %%
#insert
names.insert(1,"Yuvraj")
print(names)
# Out:
# ['Asha', 'Yuvraj', 'Sachin', 'Tashu', 'shivani']

# %%
names.insert(0,"Riya")
print(names)
# Out:
# ['Riya', 'Asha', 'Yuvraj', 'Sachin', 'Tashu', 'shivani']

# %%
#removing/deleting items
names.remove("Asha")
print(names)
# Out:
# ['Riya', 'Yuvraj', 'Sachin', 'Tashu', 'shivani']

# %%
removed=names.pop(4)
print(removed)
print(names)
# Out:
# shivani
# ['Riya', 'Yuvraj', 'Sachin', 'Tashu']

# %%
numbers=[40,50,60,70]
print(len(numbers))
# Out:
# 4

# %%
print(max(numbers))
# Out:
# 70

# %%
print(sum(numbers))
# Out:
# 220

# %%
numbers.reverse()
print(numbers)
# Out:
# [70, 60, 50, 40]

# %%
students=[["Tashu",21,"CSE"],["Riya",20,"CSE"],["Shivani",18,"CSE"]]

# %%
print(students[0])
# Out:
# ['Tashu', 21, 'CSE']

# %%
print(students[0][0])
# Out:
# Tashu

# %%
#combining lists with conditons
marks=[34,56,78,90]
for mark in marks:
  if mark>=50:
    print(mark,"Pass")
  else:
    print(mark,"Fail")
# Out:
# 34 Fail
# 56 Pass
# 78 Pass
# 90 Pass

# %% [markdown]
# MAKE A DATAFRAMe

# %%
import pandas as pd
data={
    "Customer":["A1","A2","A3","A4","A5"],
    "Age":[22,35,28,40,55],
    "City":["Delhi","Mathura","Lucknow","Varanasi","Agra"],
    "Amount":[1200,3400,6000,6700,4500],
    "Rating":[4.5,4,3.6,3,5]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Customer  Age      City  Amount  Rating
# 0       A1   22     Delhi    1200     4.5
# 1       A2   35   Mathura    3400     4.0
# 2       A3   28   Lucknow    6000     3.6
# 3       A4   40  Varanasi    6700     3.0
# 4       A5   55      Agra    4500     5.0

# %%
#first 5 rows and first 3 columns
df.iloc[0:5,0:3]
# Out:
#   Customer  Age      City
# 0       A1   22     Delhi
# 1       A2   35   Mathura
# 2       A3   28   Lucknow
# 3       A4   40  Varanasi
# 4       A5   55      Agra
